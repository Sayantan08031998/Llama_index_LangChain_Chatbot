# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/documents/Sayantan_CV.pdf
# /kaggle/input/documents/1966455-ECard.pdf
# /kaggle/input/document/CV_ Sayantan Ray.docx
# /kaggle/input/document/Feluda Samagra Vol. I (Satyajit Ray) (Z-Library).pdf
# /kaggle/input/architecture/Screenshot 2024-05-23 at 8.03.38PM.png

# %%
## Llama index is a famework connect custom data source to large language models

## we performing indexing and then we querry it to get the necessary information

### provides a lot of libraries to connect your data from different API


### structured data
### unstructured data
### semi structured data

###  best for applicaton that require quick data lookup and retreival
### focus on search centric application
### to get more data quickly


### llama index retrieves data very quickly using its indexing power

### LlamaIndex provides a in-memory vector database allowing you to run it locally, when you have a large amount of documents vector databases provides more features and better scalability and less memory constraints depending of your hardware.

# %%
from PIL import Image
import IPython.display as display
import os

# The path where the uploaded files are stored
input_path = '/kaggle/input/architecture/'

# Desired size (width, height)
new_size = (500, 500)  # You can adjust this to your desired dimensions

# Open, resize, and display the image(s)
for filename in os.listdir(input_path):
    if filename.endswith(('.png', '.jpg', '.jpeg')):  # Check for image files
        # Open the image file
        img_path = os.path.join(input_path, filename)
        img = Image.open(img_path)
        # Resize the image
        img = img.resize(new_size, Image.ANTIALIAS)
        # Display the image
        display.display(img)
# Out:
# /tmp/ipykernel_34/1495100308.py:18: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   img = img.resize(new_size, Image.ANTIALIAS)
# <PIL.Image.Image image mode=RGBA size=500x500>

# %%
### idea
### load the pdf documents
### index those pdf documents
### querry from those pdf using llama2 model
### llama 2 model we will use it from hugging face

# %%
### since we will be working with pdf we have to install the "pypdf"

# !pip install pypdf
# !pip install pypdf2
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 5.6 MB/s eta 0:00:00a 0:00:01
# ...

# %%
### Performance with spect to llama index is really high 
# !pip install transformers
# !pip install einops
# !pip instal accelerate
# !pip install langchain
# !pip install bitsandbytes
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 2.3 MB/s eta 0:00:00
# ...
# ERROR: unknown command "instal" - maybe you meant "install"
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 973.5/973.5 kB 27.1 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 308.5/308.5 kB 20.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.8/122.8 kB 8.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.5/142.5 kB 9.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 3.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.3
#     Uninstalling packaging-21.3:
#       Successfully uninstalled packaging-21.3
#   Attempting uninstall: orjson
#     Found existing installation: orjson 3.9.10
#     Uninstalling orjson-3.9.10:
#       Successfully uninstalled orjson-3.9.10
# ...

# %% [markdown]
# !pip install transformers
#
# Transformers: This is a library provided by Hugging Face that contains thousands of pre-trained models for Natural Language Processing (NLP) tasks. These models include BERT, GPT-2, T5, and many others. The library makes it easy to use these models for tasks like text classification, question answering, summarization, translation, and more. It supports PyTorch, TensorFlow, and JAX.
#
# !pip install einops
#
# Einops: This library provides a new and powerful way to handle tensor operations. "Einops" stands for "Einstein Operations" and it simplifies tensor manipulations such as reshaping, transposing, and reducing dimensions. It's particularly useful for deep learning practitioners who work with multi-dimensional arrays (tensors) and need a more readable and flexible syntax for tensor operations.
#
# !pip install accelerate
#
# Accelerate: This is another library by Hugging Face designed to help speed up the training of PyTorch models. It provides utilities to easily switch between different hardware (like CPUs, single GPUs, or multi-GPU setups) and helps in optimizing the training process for better performance and scalability. It's useful for deep learning practitioners who need to efficiently manage computational resources.
#
# !pip install langchain
#
# LangChain: LangChain is a framework designed to simplify the development of applications that involve large language models (LLMs). It provides tools for building pipelines that integrate language models with other sources of data and computation, enabling tasks like chaining prompts, managing memory, and combining different models or APIs. This can be particularly useful for creating complex NLP applications that require more than just a single model invocation.
#
# !pip install bitsandbytes
#
# BitsandBytes: This is a lightweight and efficient library for 8-bit optimizers and quantization techniques. It allows for training large-scale models with significantly reduced memory footprint and faster computation by using lower precision arithmetic (8-bit instead of the standard 16-bit or 32-bit). This can be particularly beneficial when working with large models on limited hardware resources.
#
# Summary
#
# Transformers: Provides pre-trained NLP models for various tasks.
#
# Einops: Simplifies tensor operations with a readable syntax.
#
# Accelerate: Helps optimize and manage PyTorch model training across different hardware setups.
#
# LangChain: Framework for developing applications involving large language models.
#
# BitsandBytes: Enables efficient training of large models using 8-bit precision to save memory and computational resources.

# %%
### embeddings 
# !pip install sentence_transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.5/171.5 kB 754.3 kB/s eta 0:00:00 0:00:01
# ...

# %%
### installing llama index
# !pip install llama_index
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.4/15.4 MB 89.0 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 66.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.9/147.9 kB 10.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 10.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 62.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.7/320.7 kB 21.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 52.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.2.4
#     Uninstalling nltk-3.2.4:
#       Successfully uninstalled nltk-3.2.4
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.12.2
#     Uninstalling beautifulsoup4-4.12.2:
#       Successfully uninstalled beautifulsoup4-4.12.2
# ...

# %%
# installing huggingface llm
# !pip install llama-index-llms-huggingface
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 401.3/401.3 kB 11.1 MB/s eta 0:00:0000:01
# ...
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.22.2
#     Uninstalling huggingface-hub-0.22.2:
#       Successfully uninstalled huggingface-hub-0.22.2
# ...

# %%
### calling the llama 2 model from hugging face
from llama_index.llms.huggingface import HuggingFaceLLM
# helps to interact with huggingface hubs
# Out:
# /opt/conda/lib/python3.10/site-packages/pydantic/_internal/_fields.py:160: UserWarning: Field "model_id" has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(

# %%
# vector store index stores index of embedded vector
#Simledirectory reader reads data
#ServiceContext helps to combine llama to model with promt template

from llama_index.core import VectorStoreIndex,SimpleDirectoryReader,ServiceContext

# %%
### importing simple input prompt
from llama_index.core.prompts.prompts import SimpleInputPrompt

# %%
### load the data
document = SimpleDirectoryReader("/kaggle/input/imputfile").load_data()
document
# Out:
# [Document(id_='671623f1-f920-44d5-bc3b-8b23c0fc9329', embedding=None, metadata={'page_label': '1', 'file_name': '1.pdf', 'file_path': '/kaggle/input/imputfile/1.pdf', 'file_type': 'application/pdf', 'file_size': 2685, 'creation_date': '2024-05-24', 'last_modified_date': '2024-05-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='Michael Davis  \n789 Maple Street, City, State ZIP  \n(555) 555-5555 | michaeldavis@email.com  \n  \nObjective:  \nExperienced project manager with a proven track record of delivering complex projects on time and within\nbudget. Seeking a challenging position where I can utilize my leadership skills and expertise in project \nmanagement methodologies to drive success.  \n  \nEducation:  \nMaster of Business Administration (M
# ...

# %%
### take this document apply a prompt template and use the llama 2 model for the further querry 

### default prompt

system_prompt="""
You are a Q&A assistant. Your goal is to answer questions as
accurately as possible based on the instructions and context provided.
"""
## Default format supportable by LLama2
query_wrapper_prompt=SimpleInputPrompt("<|USER|>{query_str}<|ASSISTANT|>")
query_wrapper_prompt
# Out:
# PromptTemplate(metadata={'prompt_type': <PromptType.CUSTOM: 'custom'>}, template_vars=['query_str'], kwargs={}, output_parser=None, template_var_mappings=None, function_mappings=None, template='<|USER|>{query_str}<|ASSISTANT|>')

# %%
### will do hugging face login since we are going to call the llama2 models from there
#!huggingface-cli login

# %%
### will do hugging face login since we are going to call the llama2 models from there
from huggingface_hub import login

# Replace 'your_token_here' with your actual token
token = "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"
login(token)
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %% [markdown]
# **Llama2 Model**
#
# **context window**= size of the no of tokens can be given as prompt
# **max_new_tokens**= no of new tokens that can be generated
# **temperature**- measures 0 to 1 creativity of llm models
# **query wrapper prompts**- give prompt default setup
# **tokenizer**- llama2 tokenizer from its model wit 7 billion parameters
# **model name** - same model llama2 7 b model
# **model_kwargs**- to quantize and reduce model no of bits for gpu excecution
# **datatye** of model is float16

# %%
# !pip install transformers bitsandbytes
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# ...

# %%
import torch
llm = HuggingFaceLLM(
    context_window=4096,
    max_new_tokens=256,
    generate_kwargs={"temperature": 0.0, "do_sample": False},
    system_prompt=system_prompt,
    query_wrapper_prompt=query_wrapper_prompt,
    tokenizer_name="meta-llama/Llama-2-7b-chat-hf",
    model_name="meta-llama/Llama-2-7b-chat-hf",
    device_map="auto",
    # uncomment this if using CUDA to reduce memory usage
    model_kwargs={"torch_dtype": torch.float16 , "load_in_8bit":True}
)
# Out:
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# /opt/conda/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
# !pip install -U langchain-community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 34.1 MB/s eta 0:00:00a 0:00:01
# ...

# %%
pip install llama-index-embeddings-langchain
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# **Embeddings**
# This is a sentence-transformers model: It maps sentences & paragraphs to a 768 dimensional dense vector space and can be used for tasks like clustering or semantic search.

# %%
#### take the whole document embedd it before indexing

from langchain.embeddings.huggingface import HuggingFaceEmbeddings
from llama_index.embeddings.langchain import LangchainEmbedding
embed_model=LangchainEmbedding(
    HuggingFaceEmbeddings(model_name="sentence-transformers/all-mpnet-base-v2")
)

# %% [markdown]
# **Combinng all using service Context**
#
# The service context container is a utility container for LlamaIndex index and query classes. The container contains the following objects that are commonly used for configuring every index and query, such as the LLM, the PromptHelper (for configuring input size/chunk size), the BaseEmbedding (for configuring the embedding model), and more.

# %%
### now we have the llm model 
### the pdf
## the embedding model

### we will combine them in servicecontext --- it bundle all three of them

service_context = ServiceContext.from_defaults(
chunk_size=1024,
llm=llm,
embed_model=embed_model)
# Out:
# /tmp/ipykernel_34/1462199467.py:7: DeprecationWarning: Call to deprecated class method from_defaults. (ServiceContext is deprecated, please use `llama_index.settings.Settings` instead.) -- Deprecated since version 0.10.0.
#   service_context = ServiceContext.from_defaults(

# %%
service_context
# Out:
# ServiceContext(llm_predictor=LLMPredictor(system_prompt=None, query_wrapper_prompt=None, pydantic_program_mode=<PydanticProgramMode.DEFAULT: 'default'>), prompt_helper=PromptHelper(context_window=4096, num_output=256, chunk_overlap_ratio=0.1, chunk_size_limit=None, separator=' '), embed_model=LangchainEmbedding(model_name='sentence-transformers/all-mpnet-base-v2', embed_batch_size=10, callback_manager=<llama_index.core.callbacks.base.CallbackManager object at 0x7bb991a4a5f0>, num_workers=None), transformations=[SentenceSplitter(include_metadata=True, include_prev_next_rel=True, callback_manager=<llama_index.core.callbacks.base.CallbackManager object at 0x7bb991a4a5f0>, id_func=<function default_id_func at 0x7bba1fff8160>, chunk_size=1024, chunk_overlap=200, separator=' ', paragraph_separator='\n\n\n', secondary_chunking_regex='[^,.;。？！]+[,.;。？！]?')], llama_logger=<llama_index.core.service_context_elements.llama_logger.LlamaLogger object at 0x7bb9c8c6d2d0>, callback_manager=<llama_ind
# ...

# %%
### now we will use VectorStoreIndex and convert the whole data  into index

# convert to vector from text

index = VectorStoreIndex.from_documents(document,service_context=service_context)

# %%
index

# %%
#### convert it as querry engine

# create engine to querry
query_engine=index.as_query_engine()

# %%
# store response
response = query_engine.query("what are names of candidates?")

# %%
print(response)
# Out:
# The names of the candidates are Michael Davis and John Smith.
